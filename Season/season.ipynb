# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from season import *
import types
import collections

# %%
time=np.linspace(0, 500, 700)
func = lambda x: 0.04*x
# func = 1
season = SEASON.variable_amplitude(time, f=func, b=1, c=2)
season
# Out:
# [np.float64(0.0),
#  np.float64(0.011830935356851702),
#  np.float64(-0.01630989503454641),
#  np.float64(-0.07242941186076307),
#  np.float64(-0.11318381240527453),
#  np.float64(-0.09288807229546776),
#  np.float64(0.001486708692259652),
#  np.float64(0.1326620101454748),
#  np.float64(0.22692156256635868),
#  np.float64(0.21486219069248016),
#  np.float64(0.0767872734550384),
#  np.float64(-0.13508400378003196),
#  np.float64(-0.31463295989928136),
#  np.float64(-0.35496842040974),
#  np.float64(-0.21007855979678716),
#  np.float64(0.06975066921094605),
#  np.float64(0.3524187228681737),
#  np.float64(0.48627981237308254),
#  np.float64(0.3808928634094429),
#  np.float64(0.06352449472444183),
#  np.float64(-0.32225828376080096),
#  np.float64(-0.5810783992975979),
#  np.float64(-0.5645945361747157),
#  np.float64(-0.2547422384078856),
#  np.float64(0.2145938067976958),
#  np.float64(0.6143834275336828),
#  np.float64(0.7322125194015215),
#  np.float64(0.48446652628506953),
# ...

# %%
type(time) == list or type(time) == np.ndarray or type(time) == tuple
# Out:
# True

# %%
time=np.linspace(0, 500, 700)
# season = SEASON.furier_row(time, c=(complex(2, -2), complex(-1, 1)), lamb=(-1, -3,))
season = SEASON.trigonometric_row_2(time, a0=3, a=(1,2, 8 , 10), b=(1,4, 5, 12), alpha=2, delta=0.4)

# %%
SEASON.plot_season(time, season)

# %%
SEASON.plot_spectrum(season)
